# %% [markdown]
# # Zadanie 1 Python
# ### Zadanie będzie sprawdzało podstawy wybranych funkcjonalności języka Python dla Maksymilian Łuczak
#
#
#
# 1.   Przywitaj się z użytkownikiem i pobierz od niego liczbę
# 2.   Stwórz funkcję, która będzie przyjmowała jako argument liczbę podaną przez użytkownika. Funkcja ma za zadanie sprawdzić czy liczba jest parzysta.
# 3.   Na podstawie liczby podanej przez użytkownika w pętli wypełnij listę liczbami od 1 do liczby podanej przez użytkownika.
# 4.   Oblicz sumę liczb parzystych znajdujących się w tej liście i wyświetl ją na ekran. Możesz skorzystać z wcześniej utworzonej funkcji, która sprawdza czy liczba jest parzysta.
#
# ### Zadanie sprawdza podstawy takie jak wprowadzanie danych, obsługę pętli, instrukcji warunkowych, list oraz funkcji.

# %% [markdown]
# 1.

# %%
input("Witaj, podaj liczbę: ")
# Out:
# Witaj, podaj liczbę: 1
# '1'

# %% [markdown]
# 2.

# %%
x = int(input("podaj liczbe: "))
def fun(x):
  if x % 2 == 0:
    print("parzysta")
  else:
    print("nieparzysta")

fun(x)
# Out:
# podaj liczbe: 3
# nieparzysta

# %% [markdown]
# 3.

# %%
x = int(input("podaj liczbe: "))
lista = []
for i in range(1, x):
  lista.append(i)

print(lista)
# Out:
# podaj liczbe: 5
# [1, 2, 3, 4]

# %% [markdown]
# 4.

# %%
x = int(input("podaj liczbe: "))
lista = []
for i in range(1, x):
  lista.append(i)

suma = 0
for l in lista:
  if l % 2 == 0:
    suma += l

print(suma)
# Out:
# podaj liczbe: 10
# 20
