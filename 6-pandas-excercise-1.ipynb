# %% [markdown]
# **Zanim zaczniesz pracę zapisz kopię na dysku**
#
#
#
#
# W tym zadaniu poćwiczymy pracę z **ramkami danych** w bibliotece **Pandas*** na przykładzie zbioru titanic.csv.
#
# **Plik titanic** zawiera informacje dotyczące pasażerów statku RMS Titanic, który zatonął w kwietniu 1912 roku po zderzeniu z górą lodową. Plik ten jest często używany jako zestaw danych do nauki analizy danych, modelowania przewidywań i eksploracji danych.
#
# Typowy zestaw danych titanic zawiera nastepujące kolumny:
#
# - PassengerId: Unikalny identyfikator pasażera.
# - Survived: Informacja o tym, czy pasażer przeżył katastrofę (1 - przeżył, 0 - nie przeżył).
# - Pclass: Klasa biletu pasażera (1 - pierwsza klasa, 2 - druga klasa, 3 - trzecia klasa).
# - Name: Imię i nazwisko pasażera.
# - Sex: Płeć pasażera.
# - Age: Wiek pasażera.
# - SibSp: Liczba rodzeństwa / małżonków na pokładzie.
# - Parch: Liczba rodziców / dzieci na pokładzie.
# - Ticket: Numer biletu.
# - Fare: Cena biletu.
# - Cabin: Numer kabiny pasażera.
# - Embarked: Port, w którym pasażer wszedł na pokład statku (C - Cherbourg, Q - Queenstown, S - Southampton).

# %%
# zaimportuj biblioteki: NumPy i Pandas
import numpy as np
import pandas as pd

# %%
# Pobierz zbiór danych ML-datasets z GitHub (Link: https://github.com/matzim95/ML-datasets)
# !git clone https://github.com/matzim95/ML-datasets
# Out:
# Cloning into 'ML-datasets'...
# remote: Enumerating objects: 201, done.
# remote: Counting objects: 100% (141/141), done.
# remote: Compressing objects: 100% (117/117), done.
# remote: Total 201 (delta 35), reused 124 (delta 24), pack-reused 60 (from 1)
# Receiving objects: 100% (201/201), 35.87 MiB | 12.46 MiB/s, done.
# Resolving deltas: 100% (47/47), done.
# Updating files: 100% (130/130), done.

# %%
# - Załaduj plik titanic.csv z pobranego folderu i zapisz go jako zmienną titanic.
# - Wyswietl 10 pierwszych wierszy
df = pd.read_csv('/content/ML-datasets/titanic.csv')
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# wyświtl rozmiar/kształt zbioru

df.shape
# Out:
# (891, 12)

# %%
# wyświetlanie 3 ostatnie wiersze

df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# wyswietl 3 losowe wiersze

df.sample(3)
# Out:
#      PassengerId  Survived  Pclass                               Name   Sex  \
# 549          550         1       2     Davies, Master. John Morgan Jr  male
# 26            27         0       3            Emir, Mr. Farred Chehab  male
# 408          409         0       3  Birkeland, Mr. Hans Martin Monsen  male
#
#       Age  SibSp  Parch      Ticket    Fare Cabin Embarked
# 549   8.0      1      1  C.A. 33112  36.750   NaN        S
# 26    NaN      0      0        2631   7.225   NaN        C
# 408  21.0      0      0      312992   7.775   NaN        S

# %%
# wyświetl ogólne informacje o zbiorze
# !ls "ML-datasets/titanic.csv"
df.info()
# Out:
# ML-datasets/titanic.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# wyświetl statystyki opisowe

df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# lista indeksów

df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
# lista kolumn

df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# wyświetl kolumnę 'Survived'

df['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
# Wyświetl kolumny:  'Survived' i 'Pclass'

df[['Survived', 'Pclass']]
# Out:
#      Survived  Pclass
# 0           0       3
# 1           1       1
# 2           1       3
# 3           1       1
# 4           0       3
# ..        ...     ...
# 886         0       2
# 887         1       1
# 888         0       3
# 889         1       1
# 890         0       3
#
# [891 rows x 2 columns]

# %%
# wyświetl wiersze o indeksach od 20 do 24 włacznie

df.iloc[20:25]
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  \
# 20           21         0       2           Fynney, Mr. Joseph J    male
# 21           22         1       2          Beesley, Mr. Lawrence    male
# 22           23         1       3    McGowan, Miss. Anna "Annie"  female
# 23           24         1       1   Sloper, Mr. William Thompson    male
# 24           25         0       3  Palsson, Miss. Torborg Danira  female
#
#      Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 20  35.0      0      0  239865  26.0000   NaN        S
# 21  34.0      0      0  248698  13.0000   D56        S
# 22  15.0      0      0  330923   8.0292   NaN        Q
# 23  28.0      0      0  113788  35.5000    A6        S
# 24   8.0      3      1  349909  21.0750   NaN        S

# %%
# wyświetl wszystkie kolumny dla wierszy o indeksach od 10 do 14 włacznie

df.iloc[10:15]
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 10           11         1       3       Sandstrom, Miss. Marguerite Rut
# 11           12         1       1              Bonnell, Miss. Elizabeth
# 12           13         0       3        Saundercock, Mr. William Henry
# 13           14         0       3           Andersson, Mr. Anders Johan
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
#
#        Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 10  female   4.0      1      1    PP 9549  16.7000    G6        S
# 11  female  58.0      0      0     113783  26.5500  C103        S
# 12    male  20.0      0      0  A/5. 2151   8.0500   NaN        S
# 13    male  39.0      1      5     347082  31.2750   NaN        S
# 14  female  14.0      0      0     350406   7.8542   NaN        S

# %%
# wyświetl wszystkie wiersze dla kolumny o indeksie 0

df.iloc[:, 0]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %%
# wyświetl dfragment DF dla wierszy o indeksach od 10 do 14 włacznie i kolumn o indeksach od 3 do 4 włącznie

df.iloc[10:15, 3:5]
# Out:
#                                     Name     Sex
# 10       Sandstrom, Miss. Marguerite Rut  female
# 11              Bonnell, Miss. Elizabeth  female
# 12        Saundercock, Mr. William Henry    male
# 13           Andersson, Mr. Anders Johan    male
# 14  Vestrom, Miss. Hulda Amanda Adolfina  female

# %%
# wyświetl dfragment DF dla wierszy o indeksach od 10 do 14 włacznie i kolumn o indeksach od 3 do końca

df.iloc[10:15, 3:]
# Out:
#                                     Name     Sex   Age  SibSp  Parch  \
# 10       Sandstrom, Miss. Marguerite Rut  female   4.0      1      1
# 11              Bonnell, Miss. Elizabeth  female  58.0      0      0
# 12        Saundercock, Mr. William Henry    male  20.0      0      0
# 13           Andersson, Mr. Anders Johan    male  39.0      1      5
# 14  Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0      0
#
#        Ticket     Fare Cabin Embarked
# 10    PP 9549  16.7000    G6        S
# 11     113783  26.5500  C103        S
# 12  A/5. 2151   8.0500   NaN        S
# 13     347082  31.2750   NaN        S
# 14     350406   7.8542   NaN        S

# %%
# wyświetl dfragment DF dla wierszy o indeksach od poczatku do 10 włacznie i kolumn 'Name' i 'Sex

df.loc[:10, ['Name', 'Sex']]
# Out:
#                                                  Name     Sex
# 0                             Braund, Mr. Owen Harris    male
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                              Heikkinen, Miss. Laina  female
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                            Allen, Mr. William Henry    male
# 5                                    Moran, Mr. James    male
# 6                             McCarthy, Mr. Timothy J    male
# 7                      Palsson, Master. Gosta Leonard    male
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female
# 10                    Sandstrom, Miss. Marguerite Rut  female

# %%
# Wyświetl tylko te wiersze, dla których wiek jest wiekszy od 20

df[df['Age'] > 20]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Wyświetl tylko tych pasażerów, których wiek jest niższy niż 20 lat i podrużowali w 1 klasie

df[(df['Age'] > 20) & (df['Pclass'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 867          868         0       1
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Podostuj DF od najmniejszej do największej wartości na podstaiwe kolumny 'Cabin'

df.sort_values(by='Cabin')
# Out:
#      PassengerId  Survived  Pclass  \
# 583          584         0       1
# 475          476         0       1
# 556          557         1       1
# 284          285         0       1
# 599          600         1       1
# ..           ...       ...     ...
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 888          889         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 583                                Ross, Mr. John Hugo    male  36.0      0
# 475                        Clifford, Mr. George Quincy    male   NaN      0
# 556  Duff Gordon, Lady. (Lucille Christiana Sutherl...  female  48.0      1
# 284                         Smith, Mr. Richard William    male   NaN      0
# 599       Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")    male  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Podostuj DF od najmniejszej do największej wartości na podstaiwe kolumny 'Age' i wyświetl 20 pierwszych wierszy

df_sorted = df.sort_values(by='Age')
df_sorted.head(20)
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 803          804         1       3    Thomas, Master. Assad Alexander    male
# 755          756         1       2          Hamalainen, Master. Viljo    male
# 644          645         1       3             Baclini, Miss. Eugenie  female
# 469          470         1       3      Baclini, Miss. Helene Barbara  female
# 78            79         1       2      Caldwell, Master. Alden Gates    male
# 831          832         1       2    Richards, Master. George Sibley    male
# 305          306         1       1     Allison, Master. Hudson Trevor    male
# 386          387         0       3    Goodwin, Master. Sidney Leonard    male
# 172          173         1       3       Johnson, Miss. Eleanor Ileen  female
# 183          184         1       2          Becker, Master. Richard F    male
# 164          165         0       3       Panula, Master. Eino Viljami    male
# ...

# %%
#Posortuj od największej do najmniejszej wartości na podstaiwe kolumny 'Fare'
df.sort_values(by='Fare', ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 438          439         0       1                   Fortune, Mr. Mark
# ..           ...       ...     ...                                 ...
# 806          807         0       1              Andrews, Mr. Thomas Jr
# 815          816         0       1                    Fry, Mr. Richard
# 466          467         0       2               Campbell, Mr. William
# 481          482         0       2    Frost, Mr. Anthony Wood "Archie"
# 822          823         0       1     Reuchlin, Jonkheer. John George
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
# - Utwórz mową kolumny 'Country' i uzupełnij ją 'US'
# - Wyświetl 5 pierwszych wierszy


country = 'US'
df['Country'] = country
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Country
# 0      0         A/5 21171   7.2500   NaN        S      US
# 1      0          PC 17599  71.2833   C85        C      US
# 2      0  STON/O2. 3101282   7.9250   NaN        S      US
# 3      0            113803  53.1000  C123        S      US
# ...

# %%
# Wyświetl kształt zbioru

df.shape
# Out:
# (891, 13)

# %%
# zlicz liczbę wystąpień w poszczególnych kategoriach dla zmiennej 'Survived'

df.Survived.value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# zlicz libę kobiet i mężczyzn

df.Sex.value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
# zlicz liczbę nieniulowych wartości dla zmiennej 'Age'

df['Age'].nunique()
# Out:
# 88

# %%
# minimalna wartość dla zmiennej wiek

df['Age'].min()
# Out:
# 0.42

# %%
# średnia dla zmiennej wiek

df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
# maksymalna wartość dla zmiennej wiek

df['Age'].max()
# Out:
# 80.0

# %%
# - Dodaj nową kolumnę 'New_age', w której do wieku będzie dodawane 2
# - Wyświetl 3 pierwsze wiersze


new_age = df['Age'] + 2.
df['New_age'] = new_age
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Country  New_age
# 0      0         A/5 21171   7.2500   NaN        S      US     24.0
# 1      0          PC 17599  71.2833   C85        C      US     40.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S      US     28.0

# %%
# zgrupuj dane według wartości w kolumnie 'Pclass' (klasa biletu)i obliczy średnią wartość wieku ('Age') w każdej z tych grup.


by_pclass = df.groupby('Pclass')['Age']
by_pclass.mean()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
# podaj jaka była średnia wieku dla kobiet i bężczyzn w grupie osób, które przeżyły i nie przezyły

by_pclass = df.groupby('Survived')['Age']
by_pclass.mean()
# Out:
# Survived
# 0    30.626179
# 1    28.343690
# Name: Age, dtype: float64

# %%
# Ile było osbób, które przezyły w grupie kobiet i mężczyzn


by_sex = df.groupby('Sex')['Survived']
by_sex.mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
# - Usuń kolumnę 'Country'
# - Wyswietl 4 pierwsze wiersze

df.pop('Country')
df.head(4)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-683aaa3686cd> in <cell line: 0>()
#       2 # - Wyswietl 4 pierwsze wiersze
#       3
# ----> 4 df.pop('Country')
# ...

# %%
# wyświetl kształt zbioru
# Out:
# (891, 13)

# %%
# - utwórz obiekt titanic_new1, do którego zapiszesz zbiór bez braków
# - wyświetl 5 pierwszych wierszy - zwróć uwagę na indeksy
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked  New_age
# 1       0  PC 17599  71.2833   C85        C     40.0
# 3       0    113803  53.1000  C123        S     37.0
# 6       0     17463  51.8625   E46        S     56.0
# 10      1   PP 9549  16.7000    G6        S      6.0
# ...

# %%
# - w zbiorze titanic_new1 zresetuj indeksy
# - wyświetl 3 pierwsze wiersze
# Out:
#    PassengerId  Survived  Pclass  \
# 0            2         1       1
# 1            4         1       1
# 2            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch    Ticket     Fare Cabin Embarked  New_age
# 0      0  PC 17599  71.2833   C85        C     40.0
# 1      0    113803  53.1000  C123        S     37.0
# 2      0     17463  51.8625   E46        S     56.0

# %%
# wyświetl kształt nowego zbioru i porównaj go z poprzednim wynikiem
# Out:
# (183, 13)

# %%
# Wyświetl 10 pierwszych wierszy ramki danych titanic
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# w orginalnym obiekcie (titanic) uzupełnij brakujące wartosci dla zmiennej 'Age' brakujących wartości
# Wyswietl 10 pierwszych wierszy
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  29.699118
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# ...

# %%
# w zmiennej 'Cabine' braki danych uzupełnij napisem 'unknown'
# wyświetl 3 pierwsze wiersze
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked  New_age
# 0      0         A/5 21171   7.2500  unknown        S     24.0
# 1      0          PC 17599  71.2833      C85        C     40.0
# 2      0  STON/O2. 3101282   7.9250  unknown        S     28.0

# %%
# Dodaj nową kolumnę 'Age_cat', w której pojawią dwie kategorie:
# - young dla osób poniżej 35 lat
# - old dla pozostałych

# wyswietl 5 pierwszych wierszy
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked  New_age Age_cat
# 0      0         A/5 21171   7.2500  unknown        S     24.0   young
# 1      0          PC 17599  71.2833      C85        C     40.0     old
# 2      0  STON/O2. 3101282   7.9250  unknown        S     28.0   young
# ...

# %% [markdown]
# 👍
